# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Wrangling 1

# %%
data = pd.read_csv('/content/drive/MyDrive/data/employee.csv')
data
# Out:
#       UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0             0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1             1            LIBRARY ASSISTANT                        Library
# 2             2               POLICE OFFICER  Houston Police Department-HPD
# 3             3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4             4                  ELECTRICIAN    General Services Department
# ...         ...                          ...                            ...
# 1995       1995               POLICE OFFICER  Houston Police Department-HPD
# 1996       1996       COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997               POLICE OFFICER  Houston Police Department-HPD
# 1998       1998               POLICE OFFICER  Houston Police Department-HPD
# 1999       1999                 FIRE FIGHTER  Houston Fire Department (HFD)
#
# ...

# %%
data.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# ...

# %%
data.isna()
# Out:
#       UNIQUE_ID  POSITION_TITLE  DEPARTMENT  BASE_SALARY   RACE  \
# 0         False           False       False        False  False
# 1         False           False       False        False  False
# 2         False           False       False        False  False
# 3         False           False       False        False  False
# 4         False           False       False        False  False
# ...         ...             ...         ...          ...    ...
# 1995      False           False       False        False  False
# 1996      False           False       False        False  False
# 1997      False           False       False        False  False
# 1998      False           False       False        False  False
# 1999      False           False       False        False  False
#
#       EMPLOYMENT_TYPE  GENDER  EMPLOYMENT_STATUS  HIRE_DATE  JOB_DATE
# 0               False   False              False      False     False
# ...

# %%
data.isna().sum()
# Out:
# UNIQUE_ID              0
# POSITION_TITLE         0
# DEPARTMENT             0
# BASE_SALARY          114
# RACE                  35
# EMPLOYMENT_TYPE        0
# GENDER                 0
# EMPLOYMENT_STATUS      0
# HIRE_DATE              0
# JOB_DATE               3
# dtype: int64

# %%
data.shape
# Out:
# (2000, 10)

# %%
data['BASE_SALARY'].fillna(30000,inplace=True)

# %%
data.isna().sum()
# Out:
# UNIQUE_ID             0
# POSITION_TITLE        0
# DEPARTMENT            0
# BASE_SALARY           0
# RACE                 35
# EMPLOYMENT_TYPE       0
# GENDER                0
# EMPLOYMENT_STATUS     0
# HIRE_DATE             0
# JOB_DATE              3
# dtype: int64

# %%
data['RACE'].unique()
# Out:
# array(['Hispanic/Latino', 'White', 'Black or African American',
#        'Asian/Pacific Islander', nan, 'American Indian or Alaskan Native',
#        'Others'], dtype=object)

# %%
pd.Series.mode(data['RACE'])[0]
# Out:
# 'Black or African American'

# %%
data['RACE'].fillna(pd.Series.mode(data['RACE'])[0],inplace=True)

# %%
data.isna().sum()
# Out:
# UNIQUE_ID            0
# POSITION_TITLE       0
# DEPARTMENT           0
# BASE_SALARY          0
# RACE                 0
# EMPLOYMENT_TYPE      0
# GENDER               0
# EMPLOYMENT_STATUS    0
# HIRE_DATE            0
# JOB_DATE             3
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isna().sum()
# Out:
# UNIQUE_ID            0
# POSITION_TITLE       0
# DEPARTMENT           0
# BASE_SALARY          0
# RACE                 0
# EMPLOYMENT_TYPE      0
# GENDER               0
# EMPLOYMENT_STATUS    0
# HIRE_DATE            0
# JOB_DATE             0
# dtype: int64

# %%
data.describe()
# Out:
#          UNIQUE_ID    BASE_SALARY
# count  1997.000000    1997.000000
# mean    999.649975   54315.023535
# std     577.701968   21905.344785
# min       0.000000   24960.000000
# 25%     500.000000   37336.000000
# 50%     999.000000   52514.000000
# 75%    1500.000000   66614.000000
# max    1999.000000  275000.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1997 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UNIQUE_ID          1997 non-null   int64
#  1   POSITION_TITLE     1997 non-null   object
#  2   DEPARTMENT         1997 non-null   object
#  3   BASE_SALARY        1997 non-null   float64
#  4   RACE               1997 non-null   object
#  5   EMPLOYMENT_TYPE    1997 non-null   object
#  6   GENDER             1997 non-null   object
#  7   EMPLOYMENT_STATUS  1997 non-null   object
#  8   HIRE_DATE          1997 non-null   object
#  9   JOB_DATE           1997 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 171.6+ KB

# %%
data['BASE_SALARY'] = data['BASE_SALARY'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1997 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UNIQUE_ID          1997 non-null   int64
#  1   POSITION_TITLE     1997 non-null   object
#  2   DEPARTMENT         1997 non-null   object
#  3   BASE_SALARY        1997 non-null   int64
#  4   RACE               1997 non-null   object
#  5   EMPLOYMENT_TYPE    1997 non-null   object
#  6   GENDER             1997 non-null   object
#  7   EMPLOYMENT_STATUS  1997 non-null   object
#  8   HIRE_DATE          1997 non-null   object
#  9   JOB_DATE           1997 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 171.6+ KB

# %%
data['GENDER'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data['GENDER'].replace({'Female':0,'Male':1},inplace=True)

# %%
data['GENDER'].unique()
# Out:
# array([0, 1])

# %%
data['GENDER'].sum()
# Out:
# 1395

# %%
data.shape[0] - 1395
# Out:
# 602

# %% [markdown]
# # Wrangling 2

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(df['math score'])
# Out:
# <Axes: ylabel='math score'>

# %%
new_df = df[df['math score']>30]
new_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.boxplot(new_df['math score'])
# Out:
# <Axes: ylabel='math score'>

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit_transform(new_df[['math score']])

# %% [markdown]
# # Wrangling 3

# %%
iris = pd.read_csv('/content/drive/MyDrive/datasets/iris.csv')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.groupby('species').describe().sum()
# Out:
# sepal_length  count    150.000000
#               mean      17.530000
#               std        1.504540
#               min       14.100000
#               25%       16.625000
#               50%       17.400000
#               75%       18.400000
#               max       20.700000
# sepal_width   count    150.000000
#               mean       9.162000
#               std        1.017319
#               min        6.500000
#               25%        8.450000
#               50%        9.200000
#               75%        9.850000
#               max       11.600000
# petal_length  count    150.000000
#               mean      11.276000
#               std        1.195317
#               min        8.500000
#               25%       10.500000
#               50%       11.400000
#               75%       12.050000
#               max       13.900000
# petal_width   count    150.000000
#               mean       3.596000
#               std        0.579612
# ...

# %%
iris.sepal_length.mean()
# Out:
# 5.843333333333334

# %%
iris.sepal_length.mode()
# Out:
# 0    5.0
# Name: sepal_length, dtype: float64

# %%
iris.sepal_length.median()
# Out:
# 5.8

# %%
iris.sepal_length.std()
# Out:
# 0.828066127977863

# %%
iris.sepal_length.min()
# Out:
# 4.3

# %%
iris.sepal_length.max()
# Out:
# 7.9

# %%
sns.boxplot(x=iris['species'],y=iris['sepal_length'],hue=iris['species'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# # Analytics 1

# %%
hd = pd.read_csv('/content/drive/MyDrive/datasets/HousingData.csv')
hd
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
hd.isna().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
hd['CRIM'].fillna(method='ffill',inplace=True)
hd['ZN'].fillna(method='ffill',inplace=True)
hd['INDUS'].fillna(method='ffill',inplace=True)
hd['CHAS'].fillna(method='ffill',inplace=True)
hd['AGE'].fillna(method='ffill',inplace=True)
hd['LSTAT'].fillna(method='ffill',inplace=True)

# %%
hd.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
hd.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
x=hd.iloc[:,0:13]
y=hd.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
model = make_pipeline(StandardScaler(with_mean = False), LinearRegression())
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler(with_mean=False)),
#                 ('linearregression', LinearRegression())])

# %%
model.score(x_train, y_train)
# Out:
# 0.7470213715241707

# %%
model.score(x_test, y_test)
# Out:
# 0.6666378461707106

# %% [markdown]
# # Analytics 2

# %%
social = pd.read_csv('/content/drive/MyDrive/datasets/Social_Network_Ads.csv')
social.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
social.isna().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
social['Gender'].replace({'Male':1,'Female':0},inplace=True)

# %%
x = social.drop(['Purchased','User ID'],axis = 1)
y = social['Purchased']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=30)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
x_scaled = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x_scaled,y,test_size=0.2, random_state = 30)

# %%
model_sc = LogisticRegression()
model_sc.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Analytics 3

# %%
iris = pd.read_csv('/content/drive/MyDrive/datasets/iris.csv')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
x = iris.drop(['species'],axis=1)
y = iris.drop(['sepal_length','sepal_width','petal_length','petal_width'], axis = 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state=True)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
y_pred = model.predict(x_test)
model.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9666666666666667

# %%
cm = confusion_matrix(y_test,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix = cm)
print(cm)
# Out:
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]

# %%
disp.plot()

# %%
def conf(y_true,y_pred):
  cm = confusion_matrix(y_true,y_pred)
  return (cm[0][0],cm[0][1],cm[1][0],cm[1][1])

tp , fp , fn, tn = conf(y_test, y_pred)
print(tp,fp,fn,tn)
# Out:
# 11 0 0 12

# %% [markdown]
# # Visualization 1
#
# countplot,
#
# *   histplot
# *   catplot[box,strip,bar]
# *   pairplot
# *   distplot
# *   jointplot
#
#
# num_data = dataset.select_dtypes(['int64','float64'])

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/titanic_data.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.countplot(x=titanic['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic['Age'].fillna(titanic['Age'].mode()[0],inplace = True)

# %%
titanic.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
titanic['Cabin'].fillna(titanic['Cabin'].mode()[0],inplace = True)

# %%
titanic['Embarked'].fillna(titanic['Embarked'].mode()[0],inplace = True)

# %%
titanic.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
sns.countplot(x=titanic['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x=titanic['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.histplot(titanic['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='Count'>

# %%
sns.histplot(titanic['Embarked'])
# Out:
# <Axes: xlabel='Embarked', ylabel='Count'>

# %%
sns.catplot(x='Pclass',y='Age',data=titanic,kind='box',hue='Pclass',palette='pastel')

# %% [markdown]
# sns.catplot(x=,y=,data=,kind=['box','strip']

# %%
sns.pairplot(titanic)

# %%
sns.histplot(x='PassengerId',y='Fare',bins=20,data=titanic)
# Out:
# <Axes: xlabel='PassengerId', ylabel='Fare'>

# %%
sns.distplot(titanic['Age'])
# Out:
# <ipython-input-63-0c31bc422368>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.jointplot(x=titanic['Survived'],y=titanic['Fare'],data=titanic)

# %%
num_data = titanic.select_dtypes(['float64','int64'])

temp=num_data.corr()
sns.heatmap(temp)
plt.title('Correlation')
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
sns.catplot(x='Pclass',y='Fare',data=titanic,hue='Pclass',kind='bar',palette='pastel')

# %% [markdown]
# # Visualisation 2

# %%
sns.catplot(x='Sex',y='Age',data=titanic,hue='Survived',kind='box',palette='Set2')

# %% [markdown]
# # Visualization 3

# %%
# sns.histplot(x=iris['sepal_length'],kde = True)
# sns.boxplot(iris['sepal_length'])
# sns.boxplot(x='sepal_length',y='species',data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %% [markdown]
# # practice
#
# pd.concat([df1,df2,df3],axis=1,join=)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
